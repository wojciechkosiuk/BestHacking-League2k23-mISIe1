# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# !python -m spacy download en_core_web_md
# Out:
# Collecting en-core-web-md==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.4.1/en_core_web_md-3.4.1-py3-none-any.whl (42.8 MB)
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in c:\users\wkosi\anaconda3\lib\site-packages (from en-core-web-md==3.4.1) (3.4.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\wkosi\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.0.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\wkosi\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\wkosi\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (8.1.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in c:\users\wkosi\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.0.10)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in c:\users\wkosi\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.9.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\wkosi\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (4.59.0)
# Requirement already satisfied: jinja2 in c:\users\wkosi\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.11.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\wkosi\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.10.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\wkosi\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (21.3)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\wkosi\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.21.0)
# Requirement already satisfied: setuptools in c:\users\wkosi\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (52.0.0.post20210125)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\wkosi\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.4.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\wkosi\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.0.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\wkosi\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.4.4)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\wkosi\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.6.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\wkosi\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\wkosi\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\wkosi\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.25.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\wkosi\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\wkosi\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in c:\users\wkosi\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\wkosi\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (4.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\wkosi\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\wkosi\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\wkosi\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\wkosi\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (4.0.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\wkosi\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.7.8)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\wkosi\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\wkosi\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\wkosi\anaconda3\lib\site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
df = pd.read_excel('online_retail_II.xlsx')
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# 0      2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1      2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2      2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3      2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4      2009-12-01 07:45:00   1.25      13085.0  United Kingdom
# ...                    ...    ...          ...             ...
# 525456 2010-12-09 20:01:00   2.95      17530.0  United Kingdom
# 525457 2010-12-09 20:01:00   3.75      17530.0  United Kingdom
# 525458 2010-12-09 20:01:00   3.75      17530.0  United Kingdom
# 525459 2010-12-09 20:01:00   3.75      17530.0  United Kingdom
# 525460 2010-12-09 20:01:00   1.95      17530.0  United Kingdom
#
# [525461 rows x 8 columns]

# %% [markdown]
# ## NLP Describiton Performance

# %% [markdown]
# ### Delete NaN

# %%
df2 = df[~df['Description'].isna()]
df2
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# 0      2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1      2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2      2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3      2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4      2009-12-01 07:45:00   1.25      13085.0  United Kingdom
# ...                    ...    ...          ...             ...
# 525456 2010-12-09 20:01:00   2.95      17530.0  United Kingdom
# 525457 2010-12-09 20:01:00   3.75      17530.0  United Kingdom
# 525458 2010-12-09 20:01:00   3.75      17530.0  United Kingdom
# 525459 2010-12-09 20:01:00   3.75      17530.0  United Kingdom
# 525460 2010-12-09 20:01:00   1.95      17530.0  United Kingdom
#
# [522533 rows x 8 columns]

# %%
df3 = df2.groupby(['StockCode','Description'],as_index=False).count()
df3
# Out:
#          StockCode                         Description  Invoice  Quantity  \
# 0            10002         INFLATABLE POLITICAL GLOBE       327       327
# 1            10080            GROOVY CACTUS INFLATABLE        6         6
# 2            10109                BENDY COLOUR PENCILS        1         1
# 3            10120                        DOGGY RUBBER       48        48
# 4            10120                 Zebra invcing error        1         1
# ...            ...                                 ...      ...       ...
# 5065  gift_0001_40  Dotcomgiftshop Gift Voucher £40.00        2         2
# 5066  gift_0001_50  Dotcomgiftshop Gift Voucher £50.00        2         2
# 5067  gift_0001_70  Dotcomgiftshop Gift Voucher £70.00        1         1
# 5068  gift_0001_80  Dotcomgiftshop Gift Voucher £80.00        2         2
# 5069             m                              Manual        4         4
#
#       InvoiceDate  Price  Customer ID  Country
# 0             327    327          275      327
# 1               6      6            6        6
# 2               1      1            1        1
# 3              48     48           37       48
# 4               1      1            0        1
# ...           ...    ...          ...      ...
# 5065            2      2            0        2
# 5066            2      2            0        2
# 5067            1      1            0        1
# 5068            2      2            0        2
# 5069            4      4            0        4
#
# [5070 rows x 8 columns]

# %%
import pandas as pd
import nltk
#import IProgress
import ipywidgets
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from tqdm.notebook import tqdm
tqdm.pandas()

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# Define the preprocessing function
def preprocess_text(text):
    # Tokenize the text
    tokens = word_tokenize(str(text).lower())
    # Remove stop words
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    # Lemmatize the words
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    # Join the tokens back into a string
    #preprocessed_text = ' '.join(tokens)
    return tokens

# Apply the preprocessing function to the 'Description' column
df3['Preprocessed Description'] = df3['Description'].progress_apply(preprocess_text)

df3
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\wkosi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\wkosi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\wkosi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#   0%|          | 0/5070 [00:00<?, ?it/s]
#          StockCode                         Description  Invoice  Quantity  \
# 0            10002         INFLATABLE POLITICAL GLOBE       327       327
# 1            10080            GROOVY CACTUS INFLATABLE        6         6
# 2            10109                BENDY COLOUR PENCILS        1         1
# 3            10120                        DOGGY RUBBER       48        48
# 4            10120                 Zebra invcing error        1         1
# ...            ...                                 ...      ...       ...
# 5065  gift_0001_40  Dotcomgiftshop Gift Voucher £40.00        2         2
# 5066  gift_0001_50  Dotcomgiftshop Gift Voucher £50.00        2         2
# 5067  gift_0001_70  Dotcomgiftshop Gift Voucher £70.00        1         1
# 5068  gift_0001_80  Dotcomgiftshop Gift Voucher £80.00        2         2
# 5069             m                              Manual        4         4
#
#       InvoiceDate  Price  Customer ID  Country  \
# 0             327    327          275      327
# 1               6      6            6        6
# 2               1      1            1        1
# 3              48     48           37       48
# 4               1      1            0        1
# ...           ...    ...          ...      ...
# 5065            2      2            0        2
# 5066            2      2            0        2
# 5067            1      1            0        1
# 5068            2      2            0        2
# 5069            4      4            0        4
#
#                      Preprocessed Description
# 0              [inflatable, political, globe]
# 1                [groovy, cactus, inflatable]
# 2                     [bendy, colour, pencil]
# 3                             [doggy, rubber]
# 4                     [zebra, invcing, error]
# ...                                       ...
# 5065  [dotcomgiftshop, gift, voucher, £40.00]
# 5066  [dotcomgiftshop, gift, voucher, £50.00]
# 5067  [dotcomgiftshop, gift, voucher, £70.00]
# 5068  [dotcomgiftshop, gift, voucher, £80.00]
# 5069                                 [manual]
#
# [5070 rows x 9 columns]

# %%
def clean_text(text_vec):
    return ' '.join(text_vec)

df3['clean_text'] = df3['Preprocessed Description'].progress_apply(clean_text)
df3
# Out:
#   0%|          | 0/5070 [00:00<?, ?it/s]
#          StockCode                         Description  Invoice  Quantity  \
# 0            10002         INFLATABLE POLITICAL GLOBE       327       327
# 1            10080            GROOVY CACTUS INFLATABLE        6         6
# 2            10109                BENDY COLOUR PENCILS        1         1
# 3            10120                        DOGGY RUBBER       48        48
# 4            10120                 Zebra invcing error        1         1
# ...            ...                                 ...      ...       ...
# 5065  gift_0001_40  Dotcomgiftshop Gift Voucher £40.00        2         2
# 5066  gift_0001_50  Dotcomgiftshop Gift Voucher £50.00        2         2
# 5067  gift_0001_70  Dotcomgiftshop Gift Voucher £70.00        1         1
# 5068  gift_0001_80  Dotcomgiftshop Gift Voucher £80.00        2         2
# 5069             m                              Manual        4         4
#
#       InvoiceDate  Price  Customer ID  Country  \
# 0             327    327          275      327
# 1               6      6            6        6
# 2               1      1            1        1
# 3              48     48           37       48
# 4               1      1            0        1
# ...           ...    ...          ...      ...
# 5065            2      2            0        2
# 5066            2      2            0        2
# 5067            1      1            0        1
# 5068            2      2            0        2
# 5069            4      4            0        4
#
#                      Preprocessed Description  \
# 0              [inflatable, political, globe]
# 1                [groovy, cactus, inflatable]
# 2                     [bendy, colour, pencil]
# 3                             [doggy, rubber]
# 4                     [zebra, invcing, error]
# ...                                       ...
# 5065  [dotcomgiftshop, gift, voucher, £40.00]
# 5066  [dotcomgiftshop, gift, voucher, £50.00]
# 5067  [dotcomgiftshop, gift, voucher, £70.00]
# 5068  [dotcomgiftshop, gift, voucher, £80.00]
# 5069                                 [manual]
#
#                               clean_text
# 0             inflatable political globe
# 1               groovy cactus inflatable
# 2                    bendy colour pencil
# 3                           doggy rubber
# 4                    zebra invcing error
# ...                                  ...
# 5065  dotcomgiftshop gift voucher £40.00
# 5066  dotcomgiftshop gift voucher £50.00
# 5067  dotcomgiftshop gift voucher £70.00
# 5068  dotcomgiftshop gift voucher £80.00
# 5069                              manual
#
# [5070 rows x 10 columns]

# %%
! pip3.9 install scikit-learn
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: scikit-learn in /opt/homebrew/lib/python3.9/site-packages (1.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/lib/python3.9/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /opt/homebrew/lib/python3.9/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /opt/homebrew/lib/python3.9/site-packages (from scikit-learn) (1.24.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/homebrew/lib/python3.9/site-packages (from scikit-learn) (1.2.0)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %%
from sklearn.feature_extraction.text import CountVectorizer
# Create a bag of words from the preprocessed text
vectorizer = CountVectorizer()
bag_of_words = vectorizer.fit_transform(df3['clean_text'])

# %%
# Get a list of the words in the bag of words
words = vectorizer.get_feature_names()

# Get the number of appearances of each word
word_counts = bag_of_words.sum(axis=0)

# Create a DataFrame with the word counts
word_counts_df = pd.DataFrame({'word': words, 'count': word_counts.tolist()[0]})

# %%
word_counts_df.sort_values(by=['count'],ascending=False).head(20)
# Out:
#            word  count
# 1395       pink    473
# 1639        set    416
# 234        blue    365
# 1513        red    282
# 325      candle    272
# 915       heart    247
# 2006      white    226
# 854       glass    224
# 753      flower    202
# 1972    vintage    196
# 1560       rose    188
# 255         box    185
# 142         bag    181
# 217       black    163
# 412   christmas    157
# 875       green    154
# 576      design    153
# 1170      metal    145
# 307        cake    143
# 1080      light    138

# %%
import re
colors = ['red', 'orange', 'yellow', 'green', 'blue', 'purple', 'pink', 'brown', 'black', 'white', 'gray']

# Define the function to extract color from preprocessed description
def extract_color(description):
    # Search for colors in the description
    matches = re.findall('|'.join(colors), description, flags=re.IGNORECASE)
    # If no color is found, return None
    if len(matches) == 0:
        return None
    # If multiple colors are found, return the first one
    else:
        return matches[0]

# Apply the function to the 'Preprocessed Description' column to create a new 'Color' column
df3['Color'] = df3['clean_text'].progress_apply(extract_color)
# Out:
#   0%|          | 0/5070 [00:00<?, ?it/s]

# %%
df3
# Out:
#          StockCode                         Description  Invoice  Quantity  \
# 0            10002         INFLATABLE POLITICAL GLOBE       327       327
# 1            10080            GROOVY CACTUS INFLATABLE        6         6
# 2            10109                BENDY COLOUR PENCILS        1         1
# 3            10120                        DOGGY RUBBER       48        48
# 4            10120                 Zebra invcing error        1         1
# ...            ...                                 ...      ...       ...
# 5065  gift_0001_40  Dotcomgiftshop Gift Voucher £40.00        2         2
# 5066  gift_0001_50  Dotcomgiftshop Gift Voucher £50.00        2         2
# 5067  gift_0001_70  Dotcomgiftshop Gift Voucher £70.00        1         1
# 5068  gift_0001_80  Dotcomgiftshop Gift Voucher £80.00        2         2
# 5069             m                              Manual        4         4
#
#       InvoiceDate  Price  Customer ID  Country  \
# 0             327    327          275      327
# 1               6      6            6        6
# 2               1      1            1        1
# 3              48     48           37       48
# 4               1      1            0        1
# ...           ...    ...          ...      ...
# 5065            2      2            0        2
# 5066            2      2            0        2
# 5067            1      1            0        1
# 5068            2      2            0        2
# 5069            4      4            0        4
#
#                      Preprocessed Description  \
# 0              [inflatable, political, globe]
# 1                [groovy, cactus, inflatable]
# 2                     [bendy, colour, pencil]
# 3                             [doggy, rubber]
# 4                     [zebra, invcing, error]
# ...                                       ...
# 5065  [dotcomgiftshop, gift, voucher, £40.00]
# 5066  [dotcomgiftshop, gift, voucher, £50.00]
# 5067  [dotcomgiftshop, gift, voucher, £70.00]
# 5068  [dotcomgiftshop, gift, voucher, £80.00]
# 5069                                 [manual]
#
#                               clean_text Color
# 0             inflatable political globe  None
# 1               groovy cactus inflatable  None
# 2                    bendy colour pencil  None
# 3                           doggy rubber  None
# 4                    zebra invcing error  None
# ...                                  ...   ...
# 5065  dotcomgiftshop gift voucher £40.00  None
# 5066  dotcomgiftshop gift voucher £50.00  None
# 5067  dotcomgiftshop gift voucher £70.00  None
# 5068  dotcomgiftshop gift voucher £80.00  None
# 5069                              manual  None
#
# [5070 rows x 11 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Create a TF-IDF vectorizer object
vectorizer = TfidfVectorizer()

# Fit the vectorizer to the cleaned descriptions
vectorizer.fit(df3['clean_text'])

# Transform the cleaned descriptions into TF-IDF vectors
vectors = vectorizer.transform(df3['clean_text'])

# %%
import spacy

# Load the spacy model
nlp = spacy.load('en_core_web_md')

# Function to get the Word2Vec vector for a list of words
def get_vector(full_text):
    # Initialize an empty vector
    doc = nlp(full_text)

    return doc.vector

# Apply the get_vector function to the cleaned descriptions
df3['word2vec_vector'] = df3['clean_text'].progress_apply(get_vector)
df3
# Print the resulting matrix of vectors
#vectors = np.stack(df2['word2vec_vector'].to_numpy())
#print(vectors)
# Out:
#   0%|          | 0/5070 [00:00<?, ?it/s]
#          StockCode                         Description  Invoice  Quantity  \
# 0            10002         INFLATABLE POLITICAL GLOBE       327       327
# 1            10080            GROOVY CACTUS INFLATABLE        6         6
# 2            10109                BENDY COLOUR PENCILS        1         1
# 3            10120                        DOGGY RUBBER       48        48
# 4            10120                 Zebra invcing error        1         1
# ...            ...                                 ...      ...       ...
# 5065  gift_0001_40  Dotcomgiftshop Gift Voucher £40.00        2         2
# 5066  gift_0001_50  Dotcomgiftshop Gift Voucher £50.00        2         2
# 5067  gift_0001_70  Dotcomgiftshop Gift Voucher £70.00        1         1
# 5068  gift_0001_80  Dotcomgiftshop Gift Voucher £80.00        2         2
# 5069             m                              Manual        4         4
#
#       InvoiceDate  Price  Customer ID  Country  \
# 0             327    327          275      327
# 1               6      6            6        6
# 2               1      1            1        1
# 3              48     48           37       48
# 4               1      1            0        1
# ...           ...    ...          ...      ...
# 5065            2      2            0        2
# 5066            2      2            0        2
# 5067            1      1            0        1
# 5068            2      2            0        2
# 5069            4      4            0        4
#
#                      Preprocessed Description  \
# 0              [inflatable, political, globe]
# 1                [groovy, cactus, inflatable]
# 2                     [bendy, colour, pencil]
# 3                             [doggy, rubber]
# 4                     [zebra, invcing, error]
# ...                                       ...
# 5065  [dotcomgiftshop, gift, voucher, £40.00]
# 5066  [dotcomgiftshop, gift, voucher, £50.00]
# 5067  [dotcomgiftshop, gift, voucher, £70.00]
# 5068  [dotcomgiftshop, gift, voucher, £80.00]
# 5069                                 [manual]
#
#                               clean_text Color  \
# 0             inflatable political globe  None
# 1               groovy cactus inflatable  None
# 2                    bendy colour pencil  None
# 3                           doggy rubber  None
# 4                    zebra invcing error  None
# ...                                  ...   ...
# 5065  dotcomgiftshop gift voucher £40.00  None
# 5066  dotcomgiftshop gift voucher £50.00  None
# 5067  dotcomgiftshop gift voucher £70.00  None
# 5068  dotcomgiftshop gift voucher £80.00  None
# 5069                              manual  None
#
#                                         word2vec_vector
# 0     [-0.82446665, 1.81241, -2.7604334, 1.3104668, ...
# 1     [-0.39939335, 1.3122667, -1.8237667, 2.6965332...
# 2     [-3.5454667, 3.2347336, -2.7622967, 0.39143765...
# 3     [-0.98595, 2.3052502, -3.0543, 0.9639499, -1.1...
# 4     [0.191961, 0.14209998, 0.69523335, -1.1906937,...
# ...                                                 ...
# 5065  [-2.9365, -4.17414, -5.9251943, -2.978644, -0....
# 5066  [-2.9365, -4.17414, -5.9251943, -2.978644, -0....
# 5067  [-2.9365, -4.17414, -5.9251943, -2.978644, -0....
# 5068  [-2.9365, -4.17414, -5.9251943, -2.978644, -0....
# 5069  [2.3491, 0.75755, 0.13215, 1.9341, 3.0071, -2....
#
# [5070 rows x 12 columns]

# %%
# save df3 to csv
df3.to_csv('online_retail_II_word2vec_v2.csv')

# %% [markdown]
# * For now, we don't use PCA

# %%
from sklearn.decomposition import PCA

vectors = np.array(df3['word2vec_vector'])

pca = PCA(n_components=100)

vectors_reduced = pca.fit_transform(np.stack(vectors,axis=0))

# %%
from sklearn.metrics.pairwise import cosine_similarity

# first, calculate the pairwise cosine similarity between all the vectors
similarity_matrix = cosine_similarity(np.stack(np.array(df3['word2vec_vector']),axis=0))

most_similar_indexes = []
most_similar_cosine_sims = []
for i in range(len(df3)):
    # exclude self-similarity by setting diagonal elements to -1
    similarity_matrix[i, i] = -1
    # get the indices of the 5 rows with the highest cosine similarity
    most_similar_indices = similarity_matrix[i].argsort()[:-6:-1]
    most_similar_indexes.append(most_similar_indices)
    # get the cosine similarity values of the 5 most similar rows
    most_similar_cosine_sim = similarity_matrix[i, most_similar_indices]
    most_similar_cosine_sims.append(most_similar_cosine_sim)

# add the most similar indexes and cosine similarity values as new columns in the dataframe
df3['most_similar_indexes'] = most_similar_indexes
df3['most_similar_cosine_sims'] = most_similar_cosine_sims
# # add the most similar indexes as a new column in the dataframe
# df['most_similar_idx'] = most_similar_indexes
df3
# Out:
#          StockCode                         Description  Invoice  Quantity  \
# 0            10002         INFLATABLE POLITICAL GLOBE       327       327
# 1            10080            GROOVY CACTUS INFLATABLE        6         6
# 2            10109                BENDY COLOUR PENCILS        1         1
# 3            10120                        DOGGY RUBBER       48        48
# 4            10120                 Zebra invcing error        1         1
# ...            ...                                 ...      ...       ...
# 5065  gift_0001_40  Dotcomgiftshop Gift Voucher £40.00        2         2
# 5066  gift_0001_50  Dotcomgiftshop Gift Voucher £50.00        2         2
# 5067  gift_0001_70  Dotcomgiftshop Gift Voucher £70.00        1         1
# 5068  gift_0001_80  Dotcomgiftshop Gift Voucher £80.00        2         2
# 5069             m                              Manual        4         4
#
#       InvoiceDate  Price  Customer ID  Country  \
# 0             327    327          275      327
# 1               6      6            6        6
# 2               1      1            1        1
# 3              48     48           37       48
# 4               1      1            0        1
# ...           ...    ...          ...      ...
# 5065            2      2            0        2
# 5066            2      2            0        2
# 5067            1      1            0        1
# 5068            2      2            0        2
# 5069            4      4            0        4
#
#                      Preprocessed Description  \
# 0              [inflatable, political, globe]
# 1                [groovy, cactus, inflatable]
# 2                     [bendy, colour, pencil]
# 3                             [doggy, rubber]
# 4                     [zebra, invcing, error]
# ...                                       ...
# 5065  [dotcomgiftshop, gift, voucher, £40.00]
# 5066  [dotcomgiftshop, gift, voucher, £50.00]
# 5067  [dotcomgiftshop, gift, voucher, £70.00]
# 5068  [dotcomgiftshop, gift, voucher, £80.00]
# 5069                                 [manual]
#
#                               clean_text Color  \
# 0             inflatable political globe  None
# 1               groovy cactus inflatable  None
# 2                    bendy colour pencil  None
# 3                           doggy rubber  None
# 4                    zebra invcing error  None
# ...                                  ...   ...
# 5065  dotcomgiftshop gift voucher £40.00  None
# 5066  dotcomgiftshop gift voucher £50.00  None
# 5067  dotcomgiftshop gift voucher £70.00  None
# 5068  dotcomgiftshop gift voucher £80.00  None
# 5069                              manual  None
#
#                                         word2vec_vector  \
# 0     [-0.82446665, 1.81241, -2.7604334, 1.3104668, ...
# 1     [-0.39939335, 1.3122667, -1.8237667, 2.6965332...
# 2     [-3.5454667, 3.2347336, -2.7622967, 0.39143765...
# 3     [-0.98595, 2.3052502, -3.0543, 0.9639499, -1.1...
# 4     [0.191961, 0.14209998, 0.69523335, -1.1906937,...
# ...                                                 ...
# 5065  [-2.9365, -4.17414, -5.9251943, -2.978644, -0....
# 5066  [-2.9365, -4.17414, -5.9251943, -2.978644, -0....
# 5067  [-2.9365, -4.17414, -5.9251943, -2.978644, -0....
# 5068  [-2.9365, -4.17414, -5.9251943, -2.978644, -0....
# 5069  [2.3491, 0.75755, 0.13215, 1.9341, 3.0071, -2....
#
#                 most_similar_indexes  \
# 0     [3947, 2690, 1114, 1115, 2700]
# 1      [370, 4390, 1923, 4456, 4457]
# 2              [6, 7, 8, 2665, 4843]
# 3       [3458, 33, 4118, 4129, 1253]
# 4      [3699, 1265, 284, 1858, 4717]
# ...                              ...
# 5065  [5068, 5067, 5066, 5064, 5063]
# 5066  [5068, 5067, 5065, 5064, 5063]
# 5067  [5068, 5066, 5065, 5064, 5063]
# 5068  [5067, 5066, 5065, 5064, 5063]
# 5069  [5055, 1419, 3758, 2124, 2122]
#
#                                most_similar_cosine_sims
# 0     [0.6434653, 0.62308276, 0.61678463, 0.6116491,...
# 1     [0.76041794, 0.7056728, 0.70447206, 0.70248836...
# 2     [0.7640216, 0.7640216, 0.7640216, 0.74690914, ...
# 3     [0.7346558, 0.73154896, 0.7034508, 0.7034508, ...
# 4     [0.65459305, 0.5508688, 0.5031626, 0.5013682, ...
# ...                                                 ...
# 5065  [0.9999995, 0.9999995, 0.9999995, 0.9999995, 0...
# 5066  [0.9999995, 0.9999995, 0.9999995, 0.9999995, 0...
# 5067  [0.9999995, 0.9999995, 0.9999995, 0.9999995, 0...
# 5068  [0.9999995, 0.9999995, 0.9999995, 0.9999995, 0...
# 5069  [1.0000001, 0.5305099, 0.52417266, 0.51598203,...
#
# [5070 rows x 14 columns]

# %%
df3['most_similar_cosine_sims']
# Out:
# 0       [0.6434653, 0.62308276, 0.61678463, 0.6116491,...
# 1       [0.76041794, 0.7056728, 0.70447206, 0.70248836...
# 2       [0.7640216, 0.7640216, 0.7640216, 0.74690914, ...
# 3       [0.7346558, 0.73154896, 0.7034508, 0.7034508, ...
# 4       [0.65459305, 0.5508688, 0.5031626, 0.5013682, ...
#                               ...
# 5065    [0.9999995, 0.9999995, 0.9999995, 0.9999995, 0...
# 5066    [0.9999995, 0.9999995, 0.9999995, 0.9999995, 0...
# 5067    [0.9999995, 0.9999995, 0.9999995, 0.9999995, 0...
# 5068    [0.9999995, 0.9999995, 0.9999995, 0.9999995, 0...
# 5069    [1.0000001, 0.5305099, 0.52417266, 0.51598203,...
# Name: most_similar_cosine_sims, Length: 5070, dtype: object

# %%
df3.to_csv("df_most_similar_indexes.csv")

# %% [markdown]
# ## Function

# %%
# Load the spacy model
nlp = spacy.load('en_core_web_md')

def find_most_similar_products(df3):
    df3['Preprocessed Description'] = df3['Description'].progress_apply(preprocess_text)
    df3['clean_text'] = df3['Preprocessed Description'].progress_apply(clean_text)
    df3['word2vec_vector'] = df3['clean_text'].progress_apply(get_vector)

    similarity_matrix = cosine_similarity(np.stack(np.array(df3['word2vec_vector']),axis=0))

    most_similar_indexes = []
    most_similar_cosine_sims = []
    for i in range(len(df3)):
        # exclude self-similarity by setting diagonal elements to -1
        similarity_matrix[i, i] = -1
        # get the indices of the 5 rows with the highest cosine similarity
        most_similar_indices = similarity_matrix[i].argsort()[:-6:-1]
        most_similar_indexes.append(most_similar_indices)
        # get the cosine similarity values of the 5 most similar rows
        most_similar_cosine_sim = similarity_matrix[i, most_similar_indices]
        most_similar_cosine_sims.append(most_similar_cosine_sim)

    # add the most similar indexes and cosine similarity values as new columns in the dataframe
    df3['most_similar_indexes'] = most_similar_indexes
    df3['most_similar_cosine_sims'] = most_similar_cosine_sims

    return df3

# %%
df2 = df[~df['Description'].isna()]
df3 = df2.groupby(['StockCode','Description'],as_index=False).count()
df3 = find_most_similar_products(df3)
df3
